# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import preprocessing

def relu(a, derivative=False):
    if derivative:
        return (a > 0) * 1
    f_a = np.maximum(0, a)
    return f_a  

def softmax(y):
    e_y = np.exp(y - np.max(y, axis=0))
    return e_y / np.sum(e_y, axis=0)


def sigmoid(a, derivative=False):
    f_a = (1 / (1 + np.exp(-a)))
    if derivative:
        return np.multiply(f_a, (1 - f_a))
    return f_a

class Perceptron:
    def __init__(self, previous_layer_size, activation_function=relu):
        self.theta = 0
        self.w = np.random.randn(previous_layer_size)
        self.activation = activation_function

    def y(self, inputs):
        return self.activation(np.dot(inputs, self.w) + self.theta)

# %%
# loss function
def compute_loss(self, y, y_pred):
    return -np.mean(y * np.log(y_pred) + (1 - y) * np.log(1 - y_pred))

# update NeuralNetwork class
class NeuralNetwork:
    def __init__(self, hidden_layer_activation=relu, output_layer_activation=sigmoid):
        self.input_layer = [Perceptron(2) for _ in range(2)]
        self.hidden_layer = [Perceptron(2, activation_function=hidden_layer_activation) for _ in range(4)]
        self.output_layer = [Perceptron(4, activation_function=output_layer_activation)]

    # ... rest of your code

    def forward(self, inputs):
        hidden_output = self.forward_hidden_layer(inputs)
        output_output = self.forward_output_layer(hidden_output)
        return output_output

    def forward_hidden_layer(self, inputs):
        return np.array([perceptron.y(inputs) for perceptron in self.hidden_layer])
    
    def forward_output_layer(self, inputs):
        return self.output_layer[0].y(inputs)
    
    def predict(self, X):
        y_pred = []
        for i in range(len(X)):
            hidden_output = self.forward_hidden_layer(X[i])
            output_output = self.forward_output_layer(hidden_output)
            y_pred.append(round(output_output))
        return np.array(y_pred)
    
    def train(self, X, y, epochs, learning_rate):
        loss_history = []
        accuracy_history = []
        for epoch in range(epochs):
            for i in range(len(X)):
                # forward propagation
                hidden_output = self.forward_hidden_layer(X[i])
                output_output = self.forward_output_layer(hidden_output)

                # backward propagation
                output_error = y[i] - output_output
                output_delta = 2 * output_error * self.output_layer[0].activation(output_output, derivative=True)

                hidden_error = np.dot(output_delta, self.output_layer[0].w)
                hidden_delta = hidden_error * self.hidden_layer[0].activation(hidden_output, derivative=True)

                # update weights and biases (theta)
                self.output_layer[0].w += learning_rate * output_delta * hidden_output
                self.output_layer[0].theta += learning_rate * output_error

                for j, p in enumerate(self.hidden_layer):
                    p.w += learning_rate * hidden_delta[j] * X[i]
                    p.theta += learning_rate * hidden_delta[j]
            
            # calculate loss and accuracy at the end of each epoch
            loss = self.compute_loss(y, self.predict(X))
            accuracy = np.mean(self.predict(X) == y)
            loss_history.append(loss)
            accuracy_history.append(accuracy)
            
            # print loss and accuracy for every epoch
            #print('Epoch: {}, Loss: {}, Accuracy: {}'.format(epoch, loss, accuracy))
        
        return loss_history, accuracy_history

    def compute_loss(self, y, y_pred):
        return np.mean((y - y_pred)**2)

    #def compute_loss(self, y, y_pred):
    #    return -np.mean(y * np.log(y_pred) + (1 - y) * np.log(1 - y_pred))

# %%
# Creating data

def get_data(n: int):
    X_data = np.random.rand(n, 2) * 20 - 10
    y_data = np.array([(0 if x.prod() < 0 else 1) for x in X_data])
    return X_data, y_data

# %%
# create a new network
def test_networks(X_train, y_train, X_test, y_test, learning_rate=0.1):
    activations = [('relu', relu), ('sigmoid', sigmoid)]
    networks = []
    for hidden_layer_activation in activations:
        network = NeuralNetwork(hidden_layer_activation=hidden_layer_activation[1], output_layer_activation=sigmoid)
        print(f"Neural network: hidden layer {hidden_layer_activation[0]} learning start")
        
        
        loss_history, accuracy_history = network.train(X_train, y_train, epochs=100, learning_rate=learning_rate)
        
        loss = network.compute_loss(y_test, network.predict(X_test))
        accuracy = np.mean(network.predict(X_test) == y_test)
        print(f"Test data: loss: {loss},  accuracy {accuracy}")
        
        networks.append(
            {
                "network": NeuralNetwork(hidden_layer_activation=hidden_layer_activation[1], output_layer_activation=sigmoid),
                "hidden": hidden_layer_activation[0],
                "output": "sigmoid",
                "loss": loss_history,
                "accuracy": accuracy_history
            }
        )
            
    plt.figure(figsize=(12,6))
            
    for i, network in enumerate(networks):
        plt.subplot(1,2,i+1)
        xs = range(len(network['loss']))
        plt.title(f"Hidden layer: {network['hidden']}, output: sigmoid, lr:{learning_rate}")
        plt.ylim(ymin=0, ymax=1)
        plt.plot(xs, network['loss'], label='loss')
        plt.plot(xs, network['accuracy'], label="accuracy")
        plt.legend()
    plt.show()

# %%
def l1(x):
    return (x / np.sum(np.abs(x)))

def l2(x):
    return (x / np.sqrt(np.sum(x*x)))

X_train, y_train = get_data(1000)
X_train_l1 = np.array([l1(x) for x in X_train])
X_train_l2 = np.array([l2(x) for x in X_train])

X_test, y_test = get_data(100)
X_test_l1 = np.array([l1(x) for x in X_test])
X_test_l2 = np.array([l2(x) for x in X_test])

# %%
test_networks(X_train, y_train, X_test, y_test)
# Out:
# Neural network: hidden layer relu learning start
# Epoch: 0, Loss: 0.354, Accuracy: 0.646
# Epoch: 1, Loss: 0.31, Accuracy: 0.69
# Epoch: 2, Loss: 0.314, Accuracy: 0.686
# Epoch: 3, Loss: 0.302, Accuracy: 0.698
# Epoch: 4, Loss: 0.301, Accuracy: 0.699
# Epoch: 5, Loss: 0.295, Accuracy: 0.705
# Epoch: 6, Loss: 0.296, Accuracy: 0.704
# Epoch: 7, Loss: 0.297, Accuracy: 0.703
# Epoch: 8, Loss: 0.297, Accuracy: 0.703
# Epoch: 9, Loss: 0.301, Accuracy: 0.699
# Epoch: 10, Loss: 0.304, Accuracy: 0.696
# Epoch: 11, Loss: 0.301, Accuracy: 0.699
# Epoch: 12, Loss: 0.313, Accuracy: 0.687
# Epoch: 13, Loss: 0.317, Accuracy: 0.683
# Epoch: 14, Loss: 0.312, Accuracy: 0.688
# Epoch: 15, Loss: 0.316, Accuracy: 0.684
# Epoch: 16, Loss: 0.32, Accuracy: 0.68
# Epoch: 17, Loss: 0.32, Accuracy: 0.68
# Epoch: 18, Loss: 0.322, Accuracy: 0.678
# Epoch: 19, Loss: 0.322, Accuracy: 0.678
# Epoch: 20, Loss: 0.322, Accuracy: 0.678
# Epoch: 21, Loss: 0.32, Accuracy: 0.68
# Epoch: 22, Loss: 0.321, Accuracy: 0.679
# Epoch: 23, Loss: 0.321, Accuracy: 0.679
# Epoch: 24, Loss: 0.321, Accuracy: 0.679
# Epoch: 25, Loss: 0.323, Accuracy: 0.677
# Epoch: 26, Loss: 0.321, Accuracy: 0.679
# Epoch: 27, Loss: 0.319, Accuracy: 0.681
# Epoch: 28, Loss: 0.314, Accuracy: 0.686
# Epoch: 29, Loss: 0.31, Accuracy: 0.69
# Epoch: 30, Loss: 0.322, Accuracy: 0.678
# Epoch: 31, Loss: 0.308, Accuracy: 0.692
# Epoch: 32, Loss: 0.322, Accuracy: 0.678
# Epoch: 33, Loss: 0.307, Accuracy: 0.693
# Epoch: 34, Loss: 0.32, Accuracy: 0.68
# Epoch: 35, Loss: 0.323, Accuracy: 0.677
# Epoch: 36, Loss: 0.324, Accuracy: 0.676
# Epoch: 37, Loss: 0.319, Accuracy: 0.681
# Epoch: 38, Loss: 0.323, Accuracy: 0.677
# Epoch: 39, Loss: 0.322, Accuracy: 0.678
# Epoch: 40, Loss: 0.322, Accuracy: 0.678
# Epoch: 41, Loss: 0.324, Accuracy: 0.676
# Epoch: 42, Loss: 0.315, Accuracy: 0.685
# Epoch: 43, Loss: 0.325, Accuracy: 0.675
# Epoch: 44, Loss: 0.328, Accuracy: 0.672
# Epoch: 45, Loss: 0.302, Accuracy: 0.698
# Epoch: 46, Loss: 0.319, Accuracy: 0.681
# Epoch: 47, Loss: 0.318, Accuracy: 0.682
# Epoch: 48, Loss: 0.323, Accuracy: 0.677
# Epoch: 49, Loss: 0.32, Accuracy: 0.68
# Epoch: 50, Loss: 0.324, Accuracy: 0.676
# Epoch: 51, Loss: 0.323, Accuracy: 0.677
# Epoch: 52, Loss: 0.326, Accuracy: 0.674
# Epoch: 53, Loss: 0.319, Accuracy: 0.681
# Epoch: 54, Loss: 0.32, Accuracy: 0.68
# Epoch: 55, Loss: 0.311, Accuracy: 0.689
# Epoch: 56, Loss: 0.329, Accuracy: 0.671
# Epoch: 57, Loss: 0.317, Accuracy: 0.683
# Epoch: 58, Loss: 0.316, Accuracy: 0.684
# Epoch: 59, Loss: 0.313, Accuracy: 0.687
# Epoch: 60, Loss: 0.299, Accuracy: 0.701
# Epoch: 61, Loss: 0.308, Accuracy: 0.692
# Epoch: 62, Loss: 0.306, Accuracy: 0.694
# Epoch: 63, Loss: 0.305, Accuracy: 0.695
# Epoch: 64, Loss: 0.302, Accuracy: 0.698
# Epoch: 65, Loss: 0.319, Accuracy: 0.681
# Epoch: 66, Loss: 0.326, Accuracy: 0.674
# Epoch: 67, Loss: 0.325, Accuracy: 0.675
# Epoch: 68, Loss: 0.331, Accuracy: 0.669
# Epoch: 69, Loss: 0.311, Accuracy: 0.689
# Epoch: 70, Loss: 0.315, Accuracy: 0.685
# Epoch: 71, Loss: 0.325, Accuracy: 0.675
# Epoch: 72, Loss: 0.312, Accuracy: 0.688
# Epoch: 73, Loss: 0.318, Accuracy: 0.682
# Epoch: 74, Loss: 0.324, Accuracy: 0.676
# Epoch: 75, Loss: 0.329, Accuracy: 0.671
# Epoch: 76, Loss: 0.313, Accuracy: 0.687
# Epoch: 77, Loss: 0.309, Accuracy: 0.691
# Epoch: 78, Loss: 0.328, Accuracy: 0.672
# Epoch: 79, Loss: 0.308, Accuracy: 0.692
# Epoch: 80, Loss: 0.313, Accuracy: 0.687
# Epoch: 81, Loss: 0.31, Accuracy: 0.69
# Epoch: 82, Loss: 0.326, Accuracy: 0.674
# Epoch: 83, Loss: 0.326, Accuracy: 0.674
# Epoch: 84, Loss: 0.318, Accuracy: 0.682
# Epoch: 85, Loss: 0.312, Accuracy: 0.688
# Epoch: 86, Loss: 0.318, Accuracy: 0.682
# Epoch: 87, Loss: 0.312, Accuracy: 0.688
# Epoch: 88, Loss: 0.325, Accuracy: 0.675
# Epoch: 89, Loss: 0.319, Accuracy: 0.681
# Epoch: 90, Loss: 0.317, Accuracy: 0.683
# Epoch: 91, Loss: 0.322, Accuracy: 0.678
# Epoch: 92, Loss: 0.311, Accuracy: 0.689
# Epoch: 93, Loss: 0.322, Accuracy: 0.678
# Epoch: 94, Loss: 0.318, Accuracy: 0.682
# Epoch: 95, Loss: 0.311, Accuracy: 0.689
# Epoch: 96, Loss: 0.322, Accuracy: 0.678
# Epoch: 97, Loss: 0.312, Accuracy: 0.688
# Epoch: 98, Loss: 0.321, Accuracy: 0.679
# Epoch: 99, Loss: 0.326, Accuracy: 0.674
# Test data: loss: 0.34,  accuracy 0.66
# Neural network: hidden layer sigmoid learning start
# Epoch: 0, Loss: 0.472, Accuracy: 0.528
# Epoch: 1, Loss: 0.472, Accuracy: 0.528
# Epoch: 2, Loss: 0.472, Accuracy: 0.528
# Epoch: 3, Loss: 0.472, Accuracy: 0.528
# Epoch: 4, Loss: 0.472, Accuracy: 0.528
# Epoch: 5, Loss: 0.472, Accuracy: 0.528
# Epoch: 6, Loss: 0.472, Accuracy: 0.528
# Epoch: 7, Loss: 0.472, Accuracy: 0.528
# Epoch: 8, Loss: 0.472, Accuracy: 0.528
# Epoch: 9, Loss: 0.472, Accuracy: 0.528
# Epoch: 10, Loss: 0.472, Accuracy: 0.528
# Epoch: 11, Loss: 0.472, Accuracy: 0.528
# Epoch: 12, Loss: 0.472, Accuracy: 0.528
# Epoch: 13, Loss: 0.472, Accuracy: 0.528
# Epoch: 14, Loss: 0.472, Accuracy: 0.528
# Epoch: 15, Loss: 0.472, Accuracy: 0.528
# Epoch: 16, Loss: 0.472, Accuracy: 0.528
# Epoch: 17, Loss: 0.472, Accuracy: 0.528
# Epoch: 18, Loss: 0.472, Accuracy: 0.528
# Epoch: 19, Loss: 0.472, Accuracy: 0.528
# Epoch: 20, Loss: 0.472, Accuracy: 0.528
# Epoch: 21, Loss: 0.472, Accuracy: 0.528
# Epoch: 22, Loss: 0.472, Accuracy: 0.528
# Epoch: 23, Loss: 0.472, Accuracy: 0.528
# Epoch: 24, Loss: 0.472, Accuracy: 0.528
# Epoch: 25, Loss: 0.472, Accuracy: 0.528
# Epoch: 26, Loss: 0.472, Accuracy: 0.528
# Epoch: 27, Loss: 0.472, Accuracy: 0.528
# Epoch: 28, Loss: 0.472, Accuracy: 0.528
# Epoch: 29, Loss: 0.472, Accuracy: 0.528
# Epoch: 30, Loss: 0.472, Accuracy: 0.528
# Epoch: 31, Loss: 0.472, Accuracy: 0.528
# Epoch: 32, Loss: 0.472, Accuracy: 0.528
# Epoch: 33, Loss: 0.472, Accuracy: 0.528
# Epoch: 34, Loss: 0.472, Accuracy: 0.528
# Epoch: 35, Loss: 0.472, Accuracy: 0.528
# Epoch: 36, Loss: 0.472, Accuracy: 0.528
# Epoch: 37, Loss: 0.472, Accuracy: 0.528
# Epoch: 38, Loss: 0.472, Accuracy: 0.528
# Epoch: 39, Loss: 0.472, Accuracy: 0.528
# Epoch: 40, Loss: 0.472, Accuracy: 0.528
# Epoch: 41, Loss: 0.472, Accuracy: 0.528
# Epoch: 42, Loss: 0.472, Accuracy: 0.528
# Epoch: 43, Loss: 0.472, Accuracy: 0.528
# Epoch: 44, Loss: 0.472, Accuracy: 0.528
# Epoch: 45, Loss: 0.472, Accuracy: 0.528
# Epoch: 46, Loss: 0.472, Accuracy: 0.528
# Epoch: 47, Loss: 0.472, Accuracy: 0.528
# Epoch: 48, Loss: 0.472, Accuracy: 0.528
# Epoch: 49, Loss: 0.472, Accuracy: 0.528
# Epoch: 50, Loss: 0.472, Accuracy: 0.528
# Epoch: 51, Loss: 0.472, Accuracy: 0.528
# Epoch: 52, Loss: 0.472, Accuracy: 0.528
# Epoch: 53, Loss: 0.472, Accuracy: 0.528
# Epoch: 54, Loss: 0.472, Accuracy: 0.528
# Epoch: 55, Loss: 0.472, Accuracy: 0.528
# Epoch: 56, Loss: 0.472, Accuracy: 0.528
# Epoch: 57, Loss: 0.472, Accuracy: 0.528
# Epoch: 58, Loss: 0.472, Accuracy: 0.528
# Epoch: 59, Loss: 0.472, Accuracy: 0.528
# Epoch: 60, Loss: 0.472, Accuracy: 0.528
# Epoch: 61, Loss: 0.472, Accuracy: 0.528
# Epoch: 62, Loss: 0.472, Accuracy: 0.528
# Epoch: 63, Loss: 0.472, Accuracy: 0.528
# Epoch: 64, Loss: 0.472, Accuracy: 0.528
# Epoch: 65, Loss: 0.472, Accuracy: 0.528
# Epoch: 66, Loss: 0.472, Accuracy: 0.528
# Epoch: 67, Loss: 0.472, Accuracy: 0.528
# Epoch: 68, Loss: 0.472, Accuracy: 0.528
# Epoch: 69, Loss: 0.472, Accuracy: 0.528
# Epoch: 70, Loss: 0.472, Accuracy: 0.528
# Epoch: 71, Loss: 0.472, Accuracy: 0.528
# Epoch: 72, Loss: 0.472, Accuracy: 0.528
# Epoch: 73, Loss: 0.472, Accuracy: 0.528
# Epoch: 74, Loss: 0.472, Accuracy: 0.528
# Epoch: 75, Loss: 0.472, Accuracy: 0.528
# Epoch: 76, Loss: 0.472, Accuracy: 0.528
# Epoch: 77, Loss: 0.472, Accuracy: 0.528
# Epoch: 78, Loss: 0.472, Accuracy: 0.528
# Epoch: 79, Loss: 0.472, Accuracy: 0.528
# Epoch: 80, Loss: 0.472, Accuracy: 0.528
# Epoch: 81, Loss: 0.472, Accuracy: 0.528
# Epoch: 82, Loss: 0.472, Accuracy: 0.528
# Epoch: 83, Loss: 0.472, Accuracy: 0.528
# Epoch: 84, Loss: 0.472, Accuracy: 0.528
# Epoch: 85, Loss: 0.472, Accuracy: 0.528
# Epoch: 86, Loss: 0.472, Accuracy: 0.528
# Epoch: 87, Loss: 0.472, Accuracy: 0.528
# Epoch: 88, Loss: 0.472, Accuracy: 0.528
# Epoch: 89, Loss: 0.472, Accuracy: 0.528
# Epoch: 90, Loss: 0.472, Accuracy: 0.528
# Epoch: 91, Loss: 0.472, Accuracy: 0.528
# Epoch: 92, Loss: 0.472, Accuracy: 0.528
# Epoch: 93, Loss: 0.472, Accuracy: 0.528
# Epoch: 94, Loss: 0.472, Accuracy: 0.528
# Epoch: 95, Loss: 0.472, Accuracy: 0.528
# Epoch: 96, Loss: 0.472, Accuracy: 0.528
# Epoch: 97, Loss: 0.472, Accuracy: 0.528
# Epoch: 98, Loss: 0.472, Accuracy: 0.528
# Epoch: 99, Loss: 0.472, Accuracy: 0.528
# Test data: loss: 0.48,  accuracy 0.52

# %%
test_networks(X_train_l1, y_train, X_test_l1, y_test)
# Out:
# Neural network: hidden layer relu learning start
# Epoch: 0, Loss: 0.257, Accuracy: 0.743
# Epoch: 1, Loss: 0.253, Accuracy: 0.747
# Epoch: 2, Loss: 0.253, Accuracy: 0.747
# Epoch: 3, Loss: 0.251, Accuracy: 0.749
# Epoch: 4, Loss: 0.25, Accuracy: 0.75
# Epoch: 5, Loss: 0.248, Accuracy: 0.752
# Epoch: 6, Loss: 0.253, Accuracy: 0.747
# Epoch: 7, Loss: 0.25, Accuracy: 0.75
# Epoch: 8, Loss: 0.248, Accuracy: 0.752
# Epoch: 9, Loss: 0.247, Accuracy: 0.753
# Epoch: 10, Loss: 0.247, Accuracy: 0.753
# Epoch: 11, Loss: 0.246, Accuracy: 0.754
# Epoch: 12, Loss: 0.244, Accuracy: 0.756
# Epoch: 13, Loss: 0.243, Accuracy: 0.757
# Epoch: 14, Loss: 0.243, Accuracy: 0.757
# Epoch: 15, Loss: 0.242, Accuracy: 0.758
# Epoch: 16, Loss: 0.242, Accuracy: 0.758
# Epoch: 17, Loss: 0.242, Accuracy: 0.758
# Epoch: 18, Loss: 0.242, Accuracy: 0.758
# Epoch: 19, Loss: 0.242, Accuracy: 0.758
# Epoch: 20, Loss: 0.242, Accuracy: 0.758
# Epoch: 21, Loss: 0.242, Accuracy: 0.758
# Epoch: 22, Loss: 0.242, Accuracy: 0.758
# Epoch: 23, Loss: 0.242, Accuracy: 0.758
# Epoch: 24, Loss: 0.242, Accuracy: 0.758
# Epoch: 25, Loss: 0.242, Accuracy: 0.758
# Epoch: 26, Loss: 0.242, Accuracy: 0.758
# Epoch: 27, Loss: 0.242, Accuracy: 0.758
# Epoch: 28, Loss: 0.242, Accuracy: 0.758
# Epoch: 29, Loss: 0.242, Accuracy: 0.758
# Epoch: 30, Loss: 0.242, Accuracy: 0.758
# Epoch: 31, Loss: 0.242, Accuracy: 0.758
# Epoch: 32, Loss: 0.241, Accuracy: 0.759
# Epoch: 33, Loss: 0.241, Accuracy: 0.759
# Epoch: 34, Loss: 0.241, Accuracy: 0.759
# Epoch: 35, Loss: 0.239, Accuracy: 0.761
# Epoch: 36, Loss: 0.238, Accuracy: 0.762
# Epoch: 37, Loss: 0.238, Accuracy: 0.762
# Epoch: 38, Loss: 0.238, Accuracy: 0.762
# Epoch: 39, Loss: 0.238, Accuracy: 0.762
# Epoch: 40, Loss: 0.238, Accuracy: 0.762
# Epoch: 41, Loss: 0.238, Accuracy: 0.762
# Epoch: 42, Loss: 0.238, Accuracy: 0.762
# Epoch: 43, Loss: 0.237, Accuracy: 0.763
# Epoch: 44, Loss: 0.237, Accuracy: 0.763
# Epoch: 45, Loss: 0.237, Accuracy: 0.763
# Epoch: 46, Loss: 0.237, Accuracy: 0.763
# Epoch: 47, Loss: 0.237, Accuracy: 0.763
# Epoch: 48, Loss: 0.237, Accuracy: 0.763
# Epoch: 49, Loss: 0.237, Accuracy: 0.763
# Epoch: 50, Loss: 0.237, Accuracy: 0.763
# Epoch: 51, Loss: 0.237, Accuracy: 0.763
# Epoch: 52, Loss: 0.237, Accuracy: 0.763
# Epoch: 53, Loss: 0.237, Accuracy: 0.763
# Epoch: 54, Loss: 0.237, Accuracy: 0.763
# Epoch: 55, Loss: 0.237, Accuracy: 0.763
# Epoch: 56, Loss: 0.237, Accuracy: 0.763
# Epoch: 57, Loss: 0.237, Accuracy: 0.763
# Epoch: 58, Loss: 0.237, Accuracy: 0.763
# Epoch: 59, Loss: 0.237, Accuracy: 0.763
# Epoch: 60, Loss: 0.237, Accuracy: 0.763
# Epoch: 61, Loss: 0.237, Accuracy: 0.763
# Epoch: 62, Loss: 0.237, Accuracy: 0.763
# Epoch: 63, Loss: 0.236, Accuracy: 0.764
# Epoch: 64, Loss: 0.236, Accuracy: 0.764
# Epoch: 65, Loss: 0.236, Accuracy: 0.764
# Epoch: 66, Loss: 0.236, Accuracy: 0.764
# Epoch: 67, Loss: 0.236, Accuracy: 0.764
# Epoch: 68, Loss: 0.236, Accuracy: 0.764
# Epoch: 69, Loss: 0.236, Accuracy: 0.764
# Epoch: 70, Loss: 0.236, Accuracy: 0.764
# Epoch: 71, Loss: 0.236, Accuracy: 0.764
# Epoch: 72, Loss: 0.236, Accuracy: 0.764
# Epoch: 73, Loss: 0.236, Accuracy: 0.764
# Epoch: 74, Loss: 0.236, Accuracy: 0.764
# Epoch: 75, Loss: 0.236, Accuracy: 0.764
# Epoch: 76, Loss: 0.236, Accuracy: 0.764
# Epoch: 77, Loss: 0.236, Accuracy: 0.764
# Epoch: 78, Loss: 0.236, Accuracy: 0.764
# Epoch: 79, Loss: 0.236, Accuracy: 0.764
# Epoch: 80, Loss: 0.236, Accuracy: 0.764
# Epoch: 81, Loss: 0.236, Accuracy: 0.764
# Epoch: 82, Loss: 0.236, Accuracy: 0.764
# Epoch: 83, Loss: 0.236, Accuracy: 0.764
# Epoch: 84, Loss: 0.236, Accuracy: 0.764
# Epoch: 85, Loss: 0.236, Accuracy: 0.764
# Epoch: 86, Loss: 0.236, Accuracy: 0.764
# Epoch: 87, Loss: 0.236, Accuracy: 0.764
# Epoch: 88, Loss: 0.236, Accuracy: 0.764
# Epoch: 89, Loss: 0.236, Accuracy: 0.764
# Epoch: 90, Loss: 0.236, Accuracy: 0.764
# Epoch: 91, Loss: 0.236, Accuracy: 0.764
# Epoch: 92, Loss: 0.236, Accuracy: 0.764
# Epoch: 93, Loss: 0.236, Accuracy: 0.764
# Epoch: 94, Loss: 0.236, Accuracy: 0.764
# Epoch: 95, Loss: 0.236, Accuracy: 0.764
# Epoch: 96, Loss: 0.236, Accuracy: 0.764
# Epoch: 97, Loss: 0.236, Accuracy: 0.764
# Epoch: 98, Loss: 0.236, Accuracy: 0.764
# Epoch: 99, Loss: 0.236, Accuracy: 0.764
# Test data: loss: 0.26,  accuracy 0.74
# Neural network: hidden layer sigmoid learning start
# Epoch: 0, Loss: 0.472, Accuracy: 0.528
# Epoch: 1, Loss: 0.472, Accuracy: 0.528
# Epoch: 2, Loss: 0.472, Accuracy: 0.528
# Epoch: 3, Loss: 0.472, Accuracy: 0.528
# Epoch: 4, Loss: 0.472, Accuracy: 0.528
# Epoch: 5, Loss: 0.472, Accuracy: 0.528
# Epoch: 6, Loss: 0.472, Accuracy: 0.528
# Epoch: 7, Loss: 0.472, Accuracy: 0.528
# Epoch: 8, Loss: 0.472, Accuracy: 0.528
# Epoch: 9, Loss: 0.472, Accuracy: 0.528
# Epoch: 10, Loss: 0.472, Accuracy: 0.528
# Epoch: 11, Loss: 0.472, Accuracy: 0.528
# Epoch: 12, Loss: 0.472, Accuracy: 0.528
# Epoch: 13, Loss: 0.472, Accuracy: 0.528
# Epoch: 14, Loss: 0.472, Accuracy: 0.528
# Epoch: 15, Loss: 0.472, Accuracy: 0.528
# Epoch: 16, Loss: 0.472, Accuracy: 0.528
# Epoch: 17, Loss: 0.472, Accuracy: 0.528
# Epoch: 18, Loss: 0.472, Accuracy: 0.528
# Epoch: 19, Loss: 0.472, Accuracy: 0.528
# Epoch: 20, Loss: 0.472, Accuracy: 0.528
# Epoch: 21, Loss: 0.472, Accuracy: 0.528
# Epoch: 22, Loss: 0.472, Accuracy: 0.528
# Epoch: 23, Loss: 0.472, Accuracy: 0.528
# Epoch: 24, Loss: 0.472, Accuracy: 0.528
# Epoch: 25, Loss: 0.472, Accuracy: 0.528
# Epoch: 26, Loss: 0.472, Accuracy: 0.528
# Epoch: 27, Loss: 0.472, Accuracy: 0.528
# Epoch: 28, Loss: 0.472, Accuracy: 0.528
# Epoch: 29, Loss: 0.472, Accuracy: 0.528
# Epoch: 30, Loss: 0.472, Accuracy: 0.528
# Epoch: 31, Loss: 0.472, Accuracy: 0.528
# Epoch: 32, Loss: 0.472, Accuracy: 0.528
# Epoch: 33, Loss: 0.472, Accuracy: 0.528
# Epoch: 34, Loss: 0.472, Accuracy: 0.528
# Epoch: 35, Loss: 0.472, Accuracy: 0.528
# Epoch: 36, Loss: 0.472, Accuracy: 0.528
# Epoch: 37, Loss: 0.472, Accuracy: 0.528
# Epoch: 38, Loss: 0.472, Accuracy: 0.528
# Epoch: 39, Loss: 0.472, Accuracy: 0.528
# Epoch: 40, Loss: 0.472, Accuracy: 0.528
# Epoch: 41, Loss: 0.472, Accuracy: 0.528
# Epoch: 42, Loss: 0.472, Accuracy: 0.528
# Epoch: 43, Loss: 0.472, Accuracy: 0.528
# Epoch: 44, Loss: 0.472, Accuracy: 0.528
# Epoch: 45, Loss: 0.472, Accuracy: 0.528
# Epoch: 46, Loss: 0.472, Accuracy: 0.528
# Epoch: 47, Loss: 0.472, Accuracy: 0.528
# Epoch: 48, Loss: 0.472, Accuracy: 0.528
# Epoch: 49, Loss: 0.472, Accuracy: 0.528
# Epoch: 50, Loss: 0.472, Accuracy: 0.528
# Epoch: 51, Loss: 0.472, Accuracy: 0.528
# Epoch: 52, Loss: 0.472, Accuracy: 0.528
# Epoch: 53, Loss: 0.472, Accuracy: 0.528
# Epoch: 54, Loss: 0.472, Accuracy: 0.528
# Epoch: 55, Loss: 0.472, Accuracy: 0.528
# Epoch: 56, Loss: 0.472, Accuracy: 0.528
# Epoch: 57, Loss: 0.472, Accuracy: 0.528
# Epoch: 58, Loss: 0.472, Accuracy: 0.528
# Epoch: 59, Loss: 0.472, Accuracy: 0.528
# Epoch: 60, Loss: 0.472, Accuracy: 0.528
# Epoch: 61, Loss: 0.472, Accuracy: 0.528
# Epoch: 62, Loss: 0.472, Accuracy: 0.528
# Epoch: 63, Loss: 0.472, Accuracy: 0.528
# Epoch: 64, Loss: 0.472, Accuracy: 0.528
# Epoch: 65, Loss: 0.472, Accuracy: 0.528
# Epoch: 66, Loss: 0.472, Accuracy: 0.528
# Epoch: 67, Loss: 0.472, Accuracy: 0.528
# Epoch: 68, Loss: 0.472, Accuracy: 0.528
# Epoch: 69, Loss: 0.472, Accuracy: 0.528
# Epoch: 70, Loss: 0.472, Accuracy: 0.528
# Epoch: 71, Loss: 0.472, Accuracy: 0.528
# Epoch: 72, Loss: 0.472, Accuracy: 0.528
# Epoch: 73, Loss: 0.472, Accuracy: 0.528
# Epoch: 74, Loss: 0.472, Accuracy: 0.528
# Epoch: 75, Loss: 0.472, Accuracy: 0.528
# Epoch: 76, Loss: 0.472, Accuracy: 0.528
# Epoch: 77, Loss: 0.472, Accuracy: 0.528
# Epoch: 78, Loss: 0.472, Accuracy: 0.528
# Epoch: 79, Loss: 0.472, Accuracy: 0.528
# Epoch: 80, Loss: 0.472, Accuracy: 0.528
# Epoch: 81, Loss: 0.472, Accuracy: 0.528
# Epoch: 82, Loss: 0.47, Accuracy: 0.53
# Epoch: 83, Loss: 0.471, Accuracy: 0.529
# Epoch: 84, Loss: 0.47, Accuracy: 0.53
# Epoch: 85, Loss: 0.47, Accuracy: 0.53
# Epoch: 86, Loss: 0.47, Accuracy: 0.53
# Epoch: 87, Loss: 0.471, Accuracy: 0.529
# Epoch: 88, Loss: 0.47, Accuracy: 0.53
# Epoch: 89, Loss: 0.471, Accuracy: 0.529
# Epoch: 90, Loss: 0.472, Accuracy: 0.528
# Epoch: 91, Loss: 0.472, Accuracy: 0.528
# Epoch: 92, Loss: 0.472, Accuracy: 0.528
# Epoch: 93, Loss: 0.472, Accuracy: 0.528
# Epoch: 94, Loss: 0.472, Accuracy: 0.528
# Epoch: 95, Loss: 0.472, Accuracy: 0.528
# Epoch: 96, Loss: 0.472, Accuracy: 0.528
# Epoch: 97, Loss: 0.472, Accuracy: 0.528
# Epoch: 98, Loss: 0.472, Accuracy: 0.528
# Epoch: 99, Loss: 0.472, Accuracy: 0.528
# Test data: loss: 0.48,  accuracy 0.52

# %%
test_networks(X_train_l2, y_train, X_test_l2, y_test)
# Out:
# Neural network: hidden layer relu learning start
# Epoch: 0, Loss: 0.015, Accuracy: 0.985
# Epoch: 1, Loss: 0.013, Accuracy: 0.987
# Epoch: 2, Loss: 0.016, Accuracy: 0.984
# Epoch: 3, Loss: 0.016, Accuracy: 0.984
# Epoch: 4, Loss: 0.017, Accuracy: 0.983
# Epoch: 5, Loss: 0.018, Accuracy: 0.982
# Epoch: 6, Loss: 0.018, Accuracy: 0.982
# Epoch: 7, Loss: 0.018, Accuracy: 0.982
# Epoch: 8, Loss: 0.019, Accuracy: 0.981
# Epoch: 9, Loss: 0.02, Accuracy: 0.98
# Epoch: 10, Loss: 0.02, Accuracy: 0.98
# Epoch: 11, Loss: 0.02, Accuracy: 0.98
# Epoch: 12, Loss: 0.02, Accuracy: 0.98
# Epoch: 13, Loss: 0.02, Accuracy: 0.98
# Epoch: 14, Loss: 0.019, Accuracy: 0.981
# Epoch: 15, Loss: 0.019, Accuracy: 0.981
# Epoch: 16, Loss: 0.019, Accuracy: 0.981
# Epoch: 17, Loss: 0.02, Accuracy: 0.98
# Epoch: 18, Loss: 0.02, Accuracy: 0.98
# Epoch: 19, Loss: 0.02, Accuracy: 0.98
# Epoch: 20, Loss: 0.02, Accuracy: 0.98
# Epoch: 21, Loss: 0.02, Accuracy: 0.98
# Epoch: 22, Loss: 0.02, Accuracy: 0.98
# Epoch: 23, Loss: 0.02, Accuracy: 0.98
# Epoch: 24, Loss: 0.02, Accuracy: 0.98
# Epoch: 25, Loss: 0.02, Accuracy: 0.98
# Epoch: 26, Loss: 0.02, Accuracy: 0.98
# Epoch: 27, Loss: 0.02, Accuracy: 0.98
# Epoch: 28, Loss: 0.02, Accuracy: 0.98
# Epoch: 29, Loss: 0.02, Accuracy: 0.98
# Epoch: 30, Loss: 0.02, Accuracy: 0.98
# Epoch: 31, Loss: 0.02, Accuracy: 0.98
# Epoch: 32, Loss: 0.02, Accuracy: 0.98
# Epoch: 33, Loss: 0.019, Accuracy: 0.981
# Epoch: 34, Loss: 0.019, Accuracy: 0.981
# Epoch: 35, Loss: 0.019, Accuracy: 0.981
# Epoch: 36, Loss: 0.019, Accuracy: 0.981
# Epoch: 37, Loss: 0.02, Accuracy: 0.98
# Epoch: 38, Loss: 0.02, Accuracy: 0.98
# Epoch: 39, Loss: 0.02, Accuracy: 0.98
# Epoch: 40, Loss: 0.02, Accuracy: 0.98
# Epoch: 41, Loss: 0.019, Accuracy: 0.981
# Epoch: 42, Loss: 0.019, Accuracy: 0.981
# Epoch: 43, Loss: 0.019, Accuracy: 0.981
# Epoch: 44, Loss: 0.019, Accuracy: 0.981
# Epoch: 45, Loss: 0.019, Accuracy: 0.981
# Epoch: 46, Loss: 0.019, Accuracy: 0.981
# Epoch: 47, Loss: 0.019, Accuracy: 0.981
# Epoch: 48, Loss: 0.019, Accuracy: 0.981
# Epoch: 49, Loss: 0.019, Accuracy: 0.981
# Epoch: 50, Loss: 0.019, Accuracy: 0.981
# Epoch: 51, Loss: 0.019, Accuracy: 0.981
# Epoch: 52, Loss: 0.019, Accuracy: 0.981
# Epoch: 53, Loss: 0.019, Accuracy: 0.981
# Epoch: 54, Loss: 0.019, Accuracy: 0.981
# Epoch: 55, Loss: 0.019, Accuracy: 0.981
# Epoch: 56, Loss: 0.019, Accuracy: 0.981
# Epoch: 57, Loss: 0.019, Accuracy: 0.981
# Epoch: 58, Loss: 0.019, Accuracy: 0.981
# Epoch: 59, Loss: 0.019, Accuracy: 0.981
# Epoch: 60, Loss: 0.019, Accuracy: 0.981
# Epoch: 61, Loss: 0.019, Accuracy: 0.981
# Epoch: 62, Loss: 0.019, Accuracy: 0.981
# Epoch: 63, Loss: 0.018, Accuracy: 0.982
# Epoch: 64, Loss: 0.018, Accuracy: 0.982
# Epoch: 65, Loss: 0.018, Accuracy: 0.982
# Epoch: 66, Loss: 0.018, Accuracy: 0.982
# Epoch: 67, Loss: 0.018, Accuracy: 0.982
# Epoch: 68, Loss: 0.018, Accuracy: 0.982
# Epoch: 69, Loss: 0.018, Accuracy: 0.982
# Epoch: 70, Loss: 0.018, Accuracy: 0.982
# Epoch: 71, Loss: 0.018, Accuracy: 0.982
# Epoch: 72, Loss: 0.018, Accuracy: 0.982
# Epoch: 73, Loss: 0.018, Accuracy: 0.982
# Epoch: 74, Loss: 0.018, Accuracy: 0.982
# Epoch: 75, Loss: 0.018, Accuracy: 0.982
# Epoch: 76, Loss: 0.018, Accuracy: 0.982
# Epoch: 77, Loss: 0.018, Accuracy: 0.982
# Epoch: 78, Loss: 0.018, Accuracy: 0.982
# Epoch: 79, Loss: 0.018, Accuracy: 0.982
# Epoch: 80, Loss: 0.018, Accuracy: 0.982
# Epoch: 81, Loss: 0.018, Accuracy: 0.982
# Epoch: 82, Loss: 0.018, Accuracy: 0.982
# Epoch: 83, Loss: 0.018, Accuracy: 0.982
# Epoch: 84, Loss: 0.018, Accuracy: 0.982
# Epoch: 85, Loss: 0.018, Accuracy: 0.982
# Epoch: 86, Loss: 0.018, Accuracy: 0.982
# Epoch: 87, Loss: 0.018, Accuracy: 0.982
# Epoch: 88, Loss: 0.018, Accuracy: 0.982
# Epoch: 89, Loss: 0.019, Accuracy: 0.981
# Epoch: 90, Loss: 0.019, Accuracy: 0.981
# Epoch: 91, Loss: 0.019, Accuracy: 0.981
# Epoch: 92, Loss: 0.019, Accuracy: 0.981
# Epoch: 93, Loss: 0.019, Accuracy: 0.981
# Epoch: 94, Loss: 0.019, Accuracy: 0.981
# Epoch: 95, Loss: 0.019, Accuracy: 0.981
# Epoch: 96, Loss: 0.019, Accuracy: 0.981
# Epoch: 97, Loss: 0.019, Accuracy: 0.981
# Epoch: 98, Loss: 0.018, Accuracy: 0.982
# Epoch: 99, Loss: 0.018, Accuracy: 0.982
# Test data: loss: 0.03,  accuracy 0.97
# Neural network: hidden layer sigmoid learning start
# Epoch: 0, Loss: 0.472, Accuracy: 0.528
# Epoch: 1, Loss: 0.472, Accuracy: 0.528
# Epoch: 2, Loss: 0.472, Accuracy: 0.528
# Epoch: 3, Loss: 0.472, Accuracy: 0.528
# Epoch: 4, Loss: 0.472, Accuracy: 0.528
# Epoch: 5, Loss: 0.472, Accuracy: 0.528
# Epoch: 6, Loss: 0.472, Accuracy: 0.528
# Epoch: 7, Loss: 0.472, Accuracy: 0.528
# Epoch: 8, Loss: 0.472, Accuracy: 0.528
# Epoch: 9, Loss: 0.459, Accuracy: 0.541
# Epoch: 10, Loss: 0.39, Accuracy: 0.61
# Epoch: 11, Loss: 0.36, Accuracy: 0.64
# Epoch: 12, Loss: 0.348, Accuracy: 0.652
# Epoch: 13, Loss: 0.259, Accuracy: 0.741
# Epoch: 14, Loss: 0.223, Accuracy: 0.777
# Epoch: 15, Loss: 0.195, Accuracy: 0.805
# Epoch: 16, Loss: 0.188, Accuracy: 0.812
# Epoch: 17, Loss: 0.172, Accuracy: 0.828
# Epoch: 18, Loss: 0.167, Accuracy: 0.833
# Epoch: 19, Loss: 0.153, Accuracy: 0.847
# Epoch: 20, Loss: 0.14, Accuracy: 0.86
# Epoch: 21, Loss: 0.129, Accuracy: 0.871
# Epoch: 22, Loss: 0.118, Accuracy: 0.882
# Epoch: 23, Loss: 0.116, Accuracy: 0.884
# Epoch: 24, Loss: 0.112, Accuracy: 0.888
# Epoch: 25, Loss: 0.108, Accuracy: 0.892
# Epoch: 26, Loss: 0.132, Accuracy: 0.868
# Epoch: 27, Loss: 0.156, Accuracy: 0.844
# Epoch: 28, Loss: 0.186, Accuracy: 0.814
# Epoch: 29, Loss: 0.212, Accuracy: 0.788
# Epoch: 30, Loss: 0.245, Accuracy: 0.755
# Epoch: 31, Loss: 0.271, Accuracy: 0.729
# Epoch: 32, Loss: 0.281, Accuracy: 0.719
# Epoch: 33, Loss: 0.295, Accuracy: 0.705
# Epoch: 34, Loss: 0.302, Accuracy: 0.698
# Epoch: 35, Loss: 0.308, Accuracy: 0.692
# Epoch: 36, Loss: 0.315, Accuracy: 0.685
# Epoch: 37, Loss: 0.325, Accuracy: 0.675
# Epoch: 38, Loss: 0.335, Accuracy: 0.665
# Epoch: 39, Loss: 0.351, Accuracy: 0.649
# Epoch: 40, Loss: 0.371, Accuracy: 0.629
# Epoch: 41, Loss: 0.398, Accuracy: 0.602
# Epoch: 42, Loss: 0.399, Accuracy: 0.601
# Epoch: 43, Loss: 0.397, Accuracy: 0.603
# Epoch: 44, Loss: 0.397, Accuracy: 0.603
# Epoch: 45, Loss: 0.397, Accuracy: 0.603
# Epoch: 46, Loss: 0.395, Accuracy: 0.605
# Epoch: 47, Loss: 0.394, Accuracy: 0.606
# Epoch: 48, Loss: 0.396, Accuracy: 0.604
# Epoch: 49, Loss: 0.405, Accuracy: 0.595
# Epoch: 50, Loss: 0.408, Accuracy: 0.592
# Epoch: 51, Loss: 0.418, Accuracy: 0.582
# Epoch: 52, Loss: 0.419, Accuracy: 0.581
# Epoch: 53, Loss: 0.417, Accuracy: 0.583
# Epoch: 54, Loss: 0.414, Accuracy: 0.586
# Epoch: 55, Loss: 0.413, Accuracy: 0.587
# Epoch: 56, Loss: 0.429, Accuracy: 0.571
# Epoch: 57, Loss: 0.434, Accuracy: 0.566
# Epoch: 58, Loss: 0.447, Accuracy: 0.553
# Epoch: 59, Loss: 0.455, Accuracy: 0.545
# Epoch: 60, Loss: 0.457, Accuracy: 0.543
# Epoch: 61, Loss: 0.457, Accuracy: 0.543
# Epoch: 62, Loss: 0.455, Accuracy: 0.545
# Epoch: 63, Loss: 0.452, Accuracy: 0.548
# Epoch: 64, Loss: 0.449, Accuracy: 0.551
# Epoch: 65, Loss: 0.444, Accuracy: 0.556
# Epoch: 66, Loss: 0.444, Accuracy: 0.556
# Epoch: 67, Loss: 0.445, Accuracy: 0.555
# Epoch: 68, Loss: 0.449, Accuracy: 0.551
# Epoch: 69, Loss: 0.455, Accuracy: 0.545
# Epoch: 70, Loss: 0.453, Accuracy: 0.547
# Epoch: 71, Loss: 0.458, Accuracy: 0.542
# Epoch: 72, Loss: 0.459, Accuracy: 0.541
# Epoch: 73, Loss: 0.46, Accuracy: 0.54
# Epoch: 74, Loss: 0.46, Accuracy: 0.54
# Epoch: 75, Loss: 0.46, Accuracy: 0.54
# Epoch: 76, Loss: 0.469, Accuracy: 0.531
# Epoch: 77, Loss: 0.472, Accuracy: 0.528
# Epoch: 78, Loss: 0.472, Accuracy: 0.528
# Epoch: 79, Loss: 0.476, Accuracy: 0.524
# Epoch: 80, Loss: 0.479, Accuracy: 0.521
# Epoch: 81, Loss: 0.486, Accuracy: 0.514
# Epoch: 82, Loss: 0.488, Accuracy: 0.512
# Epoch: 83, Loss: 0.49, Accuracy: 0.51
# Epoch: 84, Loss: 0.49, Accuracy: 0.51
# Epoch: 85, Loss: 0.489, Accuracy: 0.511
# Epoch: 86, Loss: 0.484, Accuracy: 0.516
# Epoch: 87, Loss: 0.482, Accuracy: 0.518
# Epoch: 88, Loss: 0.478, Accuracy: 0.522
# Epoch: 89, Loss: 0.472, Accuracy: 0.528
# Epoch: 90, Loss: 0.472, Accuracy: 0.528
# Epoch: 91, Loss: 0.472, Accuracy: 0.528
# Epoch: 92, Loss: 0.472, Accuracy: 0.528
# Epoch: 93, Loss: 0.472, Accuracy: 0.528
# Epoch: 94, Loss: 0.472, Accuracy: 0.528
# Epoch: 95, Loss: 0.472, Accuracy: 0.528
# Epoch: 96, Loss: 0.472, Accuracy: 0.528
# Epoch: 97, Loss: 0.472, Accuracy: 0.528
# Epoch: 98, Loss: 0.472, Accuracy: 0.528
# Epoch: 99, Loss: 0.472, Accuracy: 0.528
# Test data: loss: 0.48,  accuracy 0.52
